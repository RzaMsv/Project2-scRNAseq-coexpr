# %%
import pandas as pd
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# %%
gene_exp_df = pd.read_csv("gene_expression_matrixP.csv", index_col=0)
gene_exp_transposed = gene_exp_df.transpose()
# gene_exp_transposed_NAN = gene_exp_transposed.replace(0, float('nan'), inplace=True)
# gene_exp_transposed_NAN = gene_exp_transposed.replace(1, float('nan'), inplace=True)
gene_exp_transposed.head()
# Out:
#                     Mrpl15  Lypla1  Gm37988  Tcea1  Rgs20  Atp6v1h  Rb1cc1  \
# AAACCTGAGAGACGAA-1       0       0        0      0      0        0       0
# AAACCTGAGCTGCGAA-1       1       0        0      1      0        0       0
# AAACCTGAGGAATTAC-1       0       0        0      0      0        0       0
# AAACCTGCAGCTCGCA-1       1       0        0      1      0        0       0
# AAACCTGCATTGGCGC-1       0       0        0      0      0        0       0
#
#                     4732440D04Rik  Pcmtd1  Gm26901  ...  Vamp7  Tmlhe  \
# AAACCTGAGAGACGAA-1              0       1        0  ...      0      0
# AAACCTGAGCTGCGAA-1              0       1        0  ...      0      0
# AAACCTGAGGAATTAC-1              0       0        0  ...      0      0
# AAACCTGCAGCTCGCA-1              0       0        0  ...      0      0
# AAACCTGCATTGGCGC-1              0       0        0  ...      0      0
#
#                     AC133103.1  Csprs  AC125149.3  AC168977.2  AC168977.1  \
# ...

# %%
gene_exp_transposed['Pdcd1'].hist()

# set the labels and title of the histogram
plt.xlabel('Count')
plt.ylabel('Number')
plt.title('PD-1 expression')

# show the histogram
plt.show();

# %%
num_max = gene_exp_transposed['Pdcd1'].max()
num_max
# Out:
# 14

# %%
# Define the gene you want to correlate with
target_gene = "Pdcd1"

# Get the column for the target gene
target_gene_col = gene_exp_transposed[target_gene]

# Calculate correlation between target gene and all other genes
corr_df = gene_exp_transposed.corrwith(target_gene_col)

# Sort correlations in descending order
corr_df = corr_df.sort_values(ascending=False)
corr_df.to_csv("correlations.csv")

# Print top correlations
print("Top correlations with {}:".format(target_gene))
print(corr_df.head(50))
# Out:
# Top correlations with Pdcd1:
# Pdcd1       1.000000
# Bcl2a1b     0.323573
# Actg1       0.317205
# Coro1a      0.316619
# H2-D1       0.308050
# Rgs16       0.307600
# Ostf1       0.301214
# Lck         0.300706
# Rilpl2      0.298637
# S100a4      0.297539
# Ptprcap     0.293620
# Myl12a      0.292282
# Pfn1        0.286716
# Tmsb4x      0.286287
# Cotl1       0.285620
# Cfl1        0.285613
# Cd52        0.283863
# Srp14       0.283552
# Bcl2a1d     0.282401
# Capzb       0.277692
# Serf2       0.277027
# Arpc2       0.277020
# Vamp8       0.276706
# Rac2        0.275782
# Calm1       0.275643
# Ucp2        0.275408
# Rap1a       0.274179
# Zap70       0.273775
# Myl6        0.273392
# Ppp1ca      0.271713
# Cox8a       0.271660
# Cd2         0.271462
# Oaz1        0.268527
# Gapdh       0.268183
# Actr3       0.266314
# Stx11       0.263734
# Clic1       0.263246
# Cox17       0.262307
# Sh3bgrl3    0.260092
# Selk        0.259534
# Hif1a       0.259432
# Arpc5       0.258858
# ...
