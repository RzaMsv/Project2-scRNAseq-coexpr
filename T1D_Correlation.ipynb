# %%
import pandas as pd
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# %%
gene_exp_df = pd.read_csv("gene_expression_matrix.csv", index_col=0)
gene_exp_transposed = gene_exp_df.transpose()
gene_exp_transposed_NAN = gene_exp_transposed.replace(0, float('nan'), inplace=True)
gene_exp_transposed_NAN = gene_exp_transposed.replace(1, float('nan'), inplace=True)
gene_exp_transposed.head()
# Out:
#                     Mrpl15  Lypla1  Gm37988  Tcea1  Rgs20  Atp6v1h  Rb1cc1  \
# AAACCTGAGAGACGAA-1     NaN     NaN      NaN    NaN    NaN      NaN     NaN
# AAACCTGAGCTGCGAA-1     NaN     NaN      NaN    NaN    NaN      NaN     NaN
# AAACCTGAGGAATTAC-1     NaN     NaN      NaN    NaN    NaN      NaN     NaN
# AAACCTGCAGCTCGCA-1     NaN     NaN      NaN    NaN    NaN      NaN     NaN
# AAACCTGCATTGGCGC-1     NaN     NaN      NaN    NaN    NaN      NaN     NaN
#
#                     4732440D04Rik  Pcmtd1  Gm26901  ...  Vamp7  Tmlhe  \
# AAACCTGAGAGACGAA-1            NaN     NaN      NaN  ...    NaN    NaN
# AAACCTGAGCTGCGAA-1            NaN     NaN      NaN  ...    NaN    NaN
# AAACCTGAGGAATTAC-1            NaN     NaN      NaN  ...    NaN    NaN
# AAACCTGCAGCTCGCA-1            NaN     NaN      NaN  ...    NaN    NaN
# AAACCTGCATTGGCGC-1            NaN     NaN      NaN  ...    NaN    NaN
#
#                     AC133103.1  Csprs  AC125149.3  AC168977.2  AC168977.1  \
# AAACCTGAGAGACGAA-1         NaN    NaN         NaN         NaN         NaN
# AAACCTGAGCTGCGAA-1         NaN    NaN         NaN         NaN         NaN
# AAACCTGAGGAATTAC-1         NaN    NaN         NaN         NaN         NaN
# AAACCTGCAGCTCGCA-1         NaN    NaN         NaN         NaN         NaN
# AAACCTGCATTGGCGC-1         NaN    NaN         NaN         NaN         NaN
#
#                     PISD  DHRSX  CAAA01147332.1
# AAACCTGAGAGACGAA-1   NaN    NaN             NaN
# AAACCTGAGCTGCGAA-1   NaN    NaN             NaN
# AAACCTGAGGAATTAC-1   NaN    NaN             NaN
# AAACCTGCAGCTCGCA-1   NaN    NaN             NaN
# AAACCTGCATTGGCGC-1   NaN    NaN             NaN
#
# [5 rows x 12514 columns]

# %%
gene_exp_transposed['Pdcd1'].hist()

# set the labels and title of the histogram
plt.xlabel('Count')
plt.ylabel('Number')
plt.title('PD-1 expression')

# show the histogram
plt.show();

# %%
num_max = gene_exp_transposed['Pdcd1'].max()
num_max
# Out:
# 14.0

# %%
# Define the gene you want to correlate with
target_gene = "Pdcd1"

# Get the column for the target gene
target_gene_col = gene_exp_transposed[target_gene]

# Calculate correlation between target gene and all other genes
corr_df = gene_exp_transposed.corrwith(target_gene_col)

# Sort correlations in descending order
corr_df = corr_df.sort_values(ascending=False)
corr_df.to_csv("correlations.csv")

# Print top correlations
print("Top correlations with {}:".format(target_gene))
print(corr_df.head(50))
# Out:
# /Users/rezamoosavi_1/Desktop/RNAseq/env/lib/python3.10/site-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/rezamoosavi_1/Desktop/RNAseq/env/lib/python3.10/site-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# Top correlations with Pdcd1:
# Zdhhc15          1.0
# Ptcd2            1.0
# Tfb1m            1.0
# Ncln             1.0
# Serpini1         1.0
# P3h3             1.0
# Prep             1.0
# Sec24b           1.0
# F2rl2            1.0
# Eif4ebp2         1.0
# Tgtp2            1.0
# Xpnpep3          1.0
# Taf5l            1.0
# Pdcd1            1.0
# Fgl2             1.0
# Smyd5            1.0
# 2010007H06Rik    1.0
# Meg3             1.0
# Wdhd1            1.0
# Cd70             1.0
# Mgme1            1.0
# Grpel2           1.0
# Diexf            1.0
# Arl15            1.0
# Glce             1.0
# Gm26670          1.0
# Kdm3a            1.0
# Pbx4             1.0
# Zfp362           1.0
# Sidt2            1.0
# Xrcc6bp1         1.0
# Lrrc40           1.0
# Crtc2            1.0
# Dph7             1.0
# 1110012L19Rik    1.0
# Elp6             1.0
# Ttl              1.0
# A330017A19Rik    1.0
# Ftsj1            1.0
# Xlr              1.0
# Slc1a2           1.0
# Slc25a37         1.0
# 9830147E19Rik    1.0
# Stk38l           1.0
# Med24            1.0
# Myo3b            1.0
# Gm15232          1.0
# Crabp2           1.0
# Cep89            1.0
# Serpina9         1.0
# dtype: float64
